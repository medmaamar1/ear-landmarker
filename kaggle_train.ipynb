# %% [markdown]
# # Ear Landmarker Training Notebook
# This notebook clones the Ear Landmarker repository and trains a MobileNetV3-Small model using your uploaded Kaggle dataset.

# %%
# 1. Setup - Clone the repository
import os
# Change this to your actual repo URL
REPO_URL = "https://github.com/medmaamar1/ear-landmarker.git"
# !git clone {REPO_URL} .
# !pip install -r requirements.txt

# %%
# 2. Dataset Setup
# Point to your Kaggle dataset path
DATA_DIR = "/kaggle/input/datasets/maamarmohamed/ear-landmark"

import os
os.environ['DATA_DIR'] = DATA_DIR
print(f"Using dataset from: {DATA_DIR}")

# %%
# 3. Train Model
# !python train.py

# %%
# 4. Verify & Convert
# !python verify_model.py
# !pip install tensorflowjs
# !tensorflowjs_converter --input_format keras ear_landmarker_final.keras ./tfjs_model
print("Training complete! Download the 'tfjs_model' folder from Kaggle output.")
