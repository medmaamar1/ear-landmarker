# %% [markdown]
# # Ear Landmarker Training Notebook
# This notebook clones the Ear Landmarker repository, downloads the AudioEar2D dataset, and trains a MobileNetV3-Small model.

# %%
# 1. Setup - Clone the repository
import os
# Replace with your actual GitHub URL after you push the code
REPO_URL = "https://github.com/YOUR_USERNAME/ear-landmarker.git"
# !git clone {REPO_URL} .
# !pip install -r requirements.txt

# %%
# 2. Download Dataset
# !python download_ibug.py

# %%
# 3. Train Model
# !python train.py

# %%
# 4. Verify & Convert
# !python verify_model.py
# !pip install tensorflowjs
# !tensorflowjs_converter --input_format keras ear_landmarker_final.keras ./tfjs_model
print("Training complete. Check the tfjs_model/ folder for your weights!")
